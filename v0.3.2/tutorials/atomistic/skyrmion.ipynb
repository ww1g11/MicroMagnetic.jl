# %% [markdown]
# In this example, we show how to obtain a magnetic skyrmion using atomistic module in MicroMagnetic.
# We import MicroMagnetic and use double float precision in the simulation.

# %%
using MicroMagnetic
using CairoMakie

# %% [markdown]
# We create a CubicMesh

# %%
mesh =  CubicMesh(nx=120, ny=120, nz=1, pbc="xy");

# %% [markdown]
# To start the simulation, we need to give an initial state.
# We define a function in which we set the spins around site (60,60) to be negative

# %%
function m0_fun(i,j,k, dx, dy, dz)
  r2 = (i-60)^2 + (j-60)^2
  if r2 < 10^2
    return (0.1, 0, -1)
  end
  return (0,0,1)
end
# Out:
# m0_fun (generic function with 1 method)

# %% [markdown]
# We define a function to specify the problem.

# %%
function relax_system(mesh)
  #We create a simulation with 'SD' driver
  sim = Sim(mesh, driver="SD", name="skyrmion")

  #We set mu_s of the system
  set_mu_s(sim, 1.0)
  sim.driver.max_tau = 1000.0

  #Set the exchange, dmi and zeeman
  add_exch(sim, 1.0, name="exch")
  add_zeeman(sim, (0,0,3.75e-3))
  add_dmi(sim, 0.09, name="dmi")

  #Initialize the system using the `m0_fun` function
  init_m0(sim, m0_fun)

  #Relax the system
  relax(sim, maxsteps=2000, stopping_dmdt=1e-4, using_time_factor=false)

  return sim
end
# Out:
# relax_system (generic function with 1 method)

# %% [markdown]
# Recall the function

# %%
sim = relax_system(mesh);
# Out:
# [ Info: AtomisticSim has been created.
# [ Info: Static Zeeman has been added.
# [ Info: Bulk DMI for CubicMesh has been added!
# [ Info: Running Driver : MicroMagnetic.EnergyMinimization{Float64}.
# [ Info: step =    0  step_size=1.000000e-10  max_dmdt=4.193213e-01
# [ Info: step =    1  step_size=7.007519e-01  max_dmdt=4.148676e-01
# [ Info: step =    2  step_size=2.626288e-01  max_dmdt=9.675259e-01
# [ Info: step =    3  step_size=9.446246e-01  max_dmdt=1.086533e+00
# [ Info: step =    4  step_size=2.266619e-01  max_dmdt=2.009880e+00
# [ Info: step =    5  step_size=3.057373e-01  max_dmdt=1.066629e+00
# [ Info: step =    6  step_size=1.845802e-01  max_dmdt=8.133711e-01
# [ Info: step =    7  step_size=3.888033e-01  max_dmdt=7.619226e-01
# [ Info: step =    8  step_size=2.354266e-01  max_dmdt=6.322916e-01
# [ Info: step =    9  step_size=4.544976e-01  max_dmdt=5.037624e-01
# [ Info: step =   10  step_size=1.607341e-01  max_dmdt=6.585586e-01
# [ Info: step =   11  step_size=1.840325e-01  max_dmdt=2.781992e-01
# [ Info: step =   12  step_size=1.643316e-01  max_dmdt=2.509616e-01
# [ Info: step =   13  step_size=1.993566e+00  max_dmdt=2.187776e-01
# [ Info: step =   14  step_size=1.026571e+00  max_dmdt=2.534042e-01
# [ Info: step =   15  step_size=2.282515e-01  max_dmdt=1.223914e+00
# [ Info: step =   16  step_size=1.281286e-01  max_dmdt=9.397183e-01
# [ Info: step =   17  step_size=1.295310e-01  max_dmdt=8.707137e-02
# [ Info: step =   18  step_size=2.813632e-01  max_dmdt=7.827647e-02
# [ Info: step =   19  step_size=6.978297e+00  max_dmdt=7.204716e-02
# [ Info: step =   20  step_size=4.152277e+00  max_dmdt=1.212108e-01
# [ Info: step =   21  step_size=5.304798e-01  max_dmdt=9.470089e-01
# [ Info: step =   22  step_size=1.399671e-01  max_dmdt=2.502126e+00
# [ Info: step =   23  step_size=1.329527e-01  max_dmdt=1.908280e-01
# [ Info: step =   24  step_size=1.313136e-01  max_dmdt=1.036595e-01
# [ Info: step =   25  step_size=5.150176e-01  max_dmdt=6.666462e-02
# [ Info: step =   26  step_size=4.615245e-01  max_dmdt=2.866423e-02
# [ Info: step =   27  step_size=1.760813e+00  max_dmdt=2.185838e-02
# [ Info: step =   28  step_size=1.728172e-01  max_dmdt=1.198429e-01
# [ Info: step =   29  step_size=1.579905e-01  max_dmdt=3.152301e-02
# [ Info: step =   30  step_size=1.325249e-01  max_dmdt=1.974435e-02
# [ Info: step =   31  step_size=1.722419e+00  max_dmdt=1.526031e-02
# [ Info: step =   32  step_size=5.714293e-01  max_dmdt=3.029110e-02
# [ Info: step =   33  step_size=1.103040e+00  max_dmdt=2.826814e-02
# [ Info: step =   34  step_size=1.387210e-01  max_dmdt=9.450519e-02
# [ Info: step =   35  step_size=1.333642e-01  max_dmdt=4.208475e-02
# [ Info: step =   36  step_size=1.576174e-01  max_dmdt=2.385749e-02
# [ Info: step =   37  step_size=2.076334e+00  max_dmdt=1.358435e-02
# [ Info: step =   38  step_size=3.534391e-01  max_dmdt=4.783510e-02
# [ Info: step =   39  step_size=4.902958e-01  max_dmdt=2.034342e-02
# [ Info: step =   40  step_size=1.533041e-01  max_dmdt=1.749390e-02
# [ Info: step =   41  step_size=2.506386e-01  max_dmdt=1.131199e-02
# [ Info: step =   42  step_size=1.399742e-01  max_dmdt=9.376520e-03
# [ Info: step =   43  step_size=2.429420e+00  max_dmdt=8.950515e-03
# [ Info: step =   44  step_size=5.219282e-01  max_dmdt=1.037219e-02
# [ Info: step =   45  step_size=5.730238e-01  max_dmdt=2.179484e-02
# [ Info: step =   46  step_size=1.251482e-01  max_dmdt=6.681527e-02
# [ Info: step =   47  step_size=1.284230e-01  max_dmdt=8.623392e-03
# [ Info: step =   48  step_size=5.798033e-01  max_dmdt=8.235860e-03
# [ Info: step =   49  step_size=6.410632e+01  max_dmdt=7.988554e-03
# [ Info: step =   50  step_size=1.051626e+00  max_dmdt=1.822013e-01
# [ Info: step =   51  step_size=2.120439e-01  max_dmdt=7.798344e-01
# [ Info: step =   52  step_size=1.985306e-01  max_dmdt=7.456998e-02
# [ Info: step =   53  step_size=1.763888e-01  max_dmdt=2.199816e-02
# [ Info: step =   54  step_size=1.269092e-01  max_dmdt=1.874731e-02
# [ Info: step =   55  step_size=6.893543e-01  max_dmdt=1.746934e-02
# [ Info: step =   56  step_size=1.574698e+00  max_dmdt=1.726961e-02
# [ Info: step =   57  step_size=1.489335e+01  max_dmdt=1.882973e-02
# [ Info: step =   58  step_size=1.443289e-01  max_dmdt=7.154189e-01
# [ Info: step =   59  step_size=1.327443e-01  max_dmdt=3.011450e-01
# [ Info: step =   60  step_size=1.533100e-01  max_dmdt=1.654857e-01
# [ Info: step =   61  step_size=2.880342e-01  max_dmdt=7.637591e-02
# [ Info: step =   62  step_size=2.858542e-01  max_dmdt=1.163027e-02
# [ Info: step =   63  step_size=2.021499e+00  max_dmdt=7.859226e-03
# [ Info: step =   64  step_size=1.287690e-01  max_dmdt=2.850238e-02
# [ Info: step =   65  step_size=1.322534e-01  max_dmdt=8.247038e-03
# [ Info: step =   66  step_size=1.546010e-01  max_dmdt=7.014005e-03
# [ Info: step =   67  step_size=4.476359e+01  max_dmdt=6.379041e-03
# [ Info: step =   68  step_size=1.333965e+00  max_dmdt=7.333273e-02
# [ Info: step =   69  step_size=2.795640e-01  max_dmdt=3.042490e-01
# [ Info: step =   70  step_size=1.980003e-01  max_dmdt=7.289742e-02
# [ Info: step =   71  step_size=1.369334e-01  max_dmdt=3.190543e-02
# [ Info: step =   72  step_size=1.254556e-01  max_dmdt=1.250423e-02
# [ Info: step =   73  step_size=8.524491e-01  max_dmdt=1.035752e-02
# [ Info: step =   74  step_size=5.597945e-01  max_dmdt=1.130813e-02
# [ Info: step =   75  step_size=3.371356e+00  max_dmdt=9.682485e-03
# [ Info: step =   76  step_size=2.602117e-01  max_dmdt=8.031854e-02
# [ Info: step =   77  step_size=2.357710e-01  max_dmdt=1.441276e-02
# [ Info: step =   78  step_size=1.328440e-01  max_dmdt=9.674584e-03
# [ Info: step =   79  step_size=2.312176e-01  max_dmdt=5.268704e-03
# [ Info: step =   80  step_size=1.812342e-01  max_dmdt=4.941463e-03
# [ Info: step =   81  step_size=2.393265e+01  max_dmdt=4.784667e-03
# [ Info: step =   82  step_size=3.793005e-01  max_dmdt=2.989815e-02
# [ Info: step =   83  step_size=1.318603e-01  max_dmdt=5.594453e-02
# [ Info: step =   84  step_size=1.248760e-01  max_dmdt=8.528558e-03
# [ Info: step =   85  step_size=5.289877e-01  max_dmdt=7.201335e-03
# [ Info: step =   86  step_size=3.211240e+00  max_dmdt=6.682161e-03
# [ Info: step =   87  step_size=2.965036e+01  max_dmdt=6.260960e-03
# [ Info: step =   88  step_size=2.468783e-01  max_dmdt=4.094746e-01
# [ Info: step =   89  step_size=2.018529e-01  max_dmdt=1.294952e-01
# [ Info: step =   90  step_size=1.564234e-01  max_dmdt=3.276261e-02
# [ Info: step =   91  step_size=1.689855e-01  max_dmdt=1.721754e-02
# [ Info: step =   92  step_size=1.546188e-01  max_dmdt=1.231103e-02
# [ Info: step =   93  step_size=2.220298e+00  max_dmdt=1.005096e-02
# [ Info: step =   94  step_size=4.748197e-01  max_dmdt=1.621137e-02
# [ Info: step =   95  step_size=3.380379e-01  max_dmdt=1.787729e-02
# [ Info: step =   96  step_size=1.259650e-01  max_dmdt=2.187849e-02
# [ Info: step =   97  step_size=1.338803e-01  max_dmdt=5.319509e-03
# [ Info: step =   98  step_size=6.019006e-01  max_dmdt=5.143356e-03
# [ Info: step =   99  step_size=3.756077e+01  max_dmdt=4.849145e-03
# [ Info: step =  100  step_size=3.196462e+00  max_dmdt=3.076728e-02
# [ Info: step =  101  step_size=2.149148e-01  max_dmdt=4.188096e-01
# [ Info: step =  102  step_size=1.257995e-01  max_dmdt=2.451513e-01
# [ Info: step =  103  step_size=1.253836e-01  max_dmdt=2.641861e-02
# [ Info: step =  104  step_size=2.625604e-01  max_dmdt=1.895434e-02
# [ Info: step =  105  step_size=1.087706e+00  max_dmdt=8.827539e-03
# [ Info: step =  106  step_size=6.495261e-01  max_dmdt=9.713121e-03
# [ Info: step =  107  step_size=2.041880e+00  max_dmdt=1.308124e-02
# [ Info: step =  108  step_size=1.822571e-01  max_dmdt=9.841340e-02
# [ Info: step =  109  step_size=1.724610e-01  max_dmdt=2.093475e-02
# [ Info: step =  110  step_size=1.540197e-01  max_dmdt=9.196345e-03
# [ Info: step =  111  step_size=1.239447e+00  max_dmdt=5.942973e-03
# [ Info: step =  112  step_size=3.435909e-01  max_dmdt=1.275938e-02
# [ Info: step =  113  step_size=7.363391e-01  max_dmdt=6.763936e-03
# [ Info: step =  114  step_size=1.286794e-01  max_dmdt=2.311248e-02
# [ Info: step =  115  step_size=1.418068e-01  max_dmdt=4.379363e-03
# [ Info: step =  116  step_size=1.689568e-01  max_dmdt=3.906058e-03
# [ Info: step =  117  step_size=6.032812e+01  max_dmdt=3.753275e-03
# [ Info: step =  118  step_size=4.377312e+00  max_dmdt=4.504922e-02
# [ Info: step =  119  step_size=4.092722e-01  max_dmdt=4.996935e-01
# [ Info: step =  120  step_size=1.323993e-01  max_dmdt=5.624627e-01
# [ Info: step =  121  step_size=1.254162e-01  max_dmdt=9.415263e-02
# [ Info: step =  122  step_size=1.361282e-01  max_dmdt=4.230155e-02
# [ Info: step =  123  step_size=3.819034e-01  max_dmdt=2.380971e-02
# [ Info: step =  124  step_size=3.145319e-01  max_dmdt=8.106005e-03
# [ Info: step =  125  step_size=3.426859e+00  max_dmdt=6.240961e-03
# [ Info: step =  126  step_size=9.029536e-01  max_dmdt=1.113266e-02
# [ Info: step =  127  step_size=3.771515e-01  max_dmdt=4.331958e-02
# [ Info: step =  128  step_size=1.698322e-01  max_dmdt=4.291319e-02
# [ Info: step =  129  step_size=1.601499e-01  max_dmdt=9.374790e-03
# [ Info: step =  130  step_size=1.293093e-01  max_dmdt=3.851236e-03
# [ Info: step =  131  step_size=1.331275e+00  max_dmdt=3.100366e-03
# [ Info: step =  132  step_size=7.677286e-01  max_dmdt=3.714276e-03
# [ Info: step =  133  step_size=4.499748e+00  max_dmdt=6.818230e-03
# [ Info: step =  134  step_size=1.394838e-01  max_dmdt=1.573074e-01
# [ Info: step =  135  step_size=1.343536e-01  max_dmdt=3.755761e-02
# [ Info: step =  136  step_size=1.528423e-01  max_dmdt=1.165599e-02
# [ Info: step =  137  step_size=3.950506e-01  max_dmdt=4.056699e-03
# [ Info: step =  138  step_size=2.120948e-01  max_dmdt=3.775068e-03
# [ Info: step =  139  step_size=3.220567e+00  max_dmdt=2.474387e-03
# [ Info: step =  140  step_size=1.397943e-01  max_dmdt=7.011592e-03
# [ Info: step =  141  step_size=1.757723e-01  max_dmdt=2.764836e-03
# [ Info: step =  142  step_size=1.313956e-01  max_dmdt=2.418777e-03
# [ Info: step =  143  step_size=1.978604e+01  max_dmdt=2.310347e-03
# [ Info: step =  144  step_size=1.225245e+00  max_dmdt=9.016270e-03
# [ Info: step =  145  step_size=3.646405e-01  max_dmdt=3.469132e-02
# [ Info: step =  146  step_size=1.299344e-01  max_dmdt=4.077677e-02
# [ Info: step =  147  step_size=1.266100e-01  max_dmdt=5.701393e-03
# [ Info: step =  148  step_size=1.551161e-01  max_dmdt=3.212478e-03
# [ Info: step =  149  step_size=4.127324e+00  max_dmdt=2.296709e-03
# [ Info: step =  150  step_size=2.616321e-01  max_dmdt=1.252963e-02
# [ Info: step =  151  step_size=3.741060e-01  max_dmdt=3.042007e-03
# [ Info: step =  152  step_size=2.022708e-01  max_dmdt=2.949519e-03
# [ Info: step =  153  step_size=4.223681e+00  max_dmdt=2.237448e-03
# [ Info: step =  154  step_size=1.314305e-01  max_dmdt=9.257492e-03
# [ Info: step =  155  step_size=1.483818e-01  max_dmdt=2.577082e-03
# [ Info: step =  156  step_size=1.444914e-01  max_dmdt=2.148341e-03
# [ Info: step =  157  step_size=8.361532e+01  max_dmdt=2.061137e-03
# [ Info: step =  158  step_size=6.002004e-01  max_dmdt=4.927319e-02
# [ Info: step =  159  step_size=2.175532e-01  max_dmdt=8.830459e-02
# [ Info: step =  160  step_size=1.412468e-01  max_dmdt=3.124077e-02
# [ Info: step =  161  step_size=1.282653e-01  max_dmdt=8.686628e-03
# [ Info: step =  162  step_size=1.338297e-01  max_dmdt=3.825511e-03
# [ Info: step =  163  step_size=2.951033e+00  max_dmdt=2.429464e-03
# [ Info: step =  164  step_size=3.126348e-01  max_dmdt=1.536960e-02
# [ Info: step =  165  step_size=4.103586e-01  max_dmdt=2.195735e-03
# [ Info: step =  166  step_size=1.893850e-01  max_dmdt=2.189707e-03
# [ Info: step =  167  step_size=3.426496e+00  max_dmdt=1.928552e-03
# [ Info: step =  168  step_size=1.316090e-01  max_dmdt=7.794568e-03
# [ Info: step =  169  step_size=1.491229e-01  max_dmdt=2.013641e-03
# [ Info: step =  170  step_size=1.438154e-01  max_dmdt=1.794926e-03
# [ Info: step =  171  step_size=7.335370e+01  max_dmdt=1.727115e-03
# [ Info: step =  172  step_size=5.870855e-01  max_dmdt=5.387671e-02
# [ Info: step =  173  step_size=2.438637e-01  max_dmdt=7.253466e-02
# [ Info: step =  174  step_size=1.413041e-01  max_dmdt=2.431155e-02
# [ Info: step =  175  step_size=1.273663e-01  max_dmdt=5.817570e-03
# [ Info: step =  176  step_size=1.290662e-01  max_dmdt=3.314716e-03
# [ Info: step =  177  step_size=5.475149e+00  max_dmdt=2.587429e-03
# [ Info: step =  178  step_size=4.114303e-01  max_dmdt=2.074970e-02
# [ Info: step =  179  step_size=3.599161e-01  max_dmdt=8.182754e-03
# [ Info: step =  180  step_size=2.699513e-01  max_dmdt=3.176973e-03
# [ Info: step =  181  step_size=1.821259e+00  max_dmdt=1.738642e-03
# [ Info: step =  182  step_size=1.312046e-01  max_dmdt=7.101314e-03
# [ Info: step =  183  step_size=1.477883e-01  max_dmdt=1.857980e-03
# [ Info: step =  184  step_size=1.642776e-01  max_dmdt=1.439314e-03
# [ Info: step =  185  step_size=4.261866e+01  max_dmdt=1.363425e-03
# [ Info: step =  186  step_size=5.747682e-01  max_dmdt=2.461839e-02
# [ Info: step =  187  step_size=2.072369e-01  max_dmdt=3.990016e-02
# [ Info: step =  188  step_size=1.316920e-01  max_dmdt=1.681606e-02
# [ Info: step =  189  step_size=1.292802e-01  max_dmdt=3.650688e-03
# [ Info: step =  190  step_size=1.552641e-01  max_dmdt=2.511735e-03
# [ Info: step =  191  step_size=6.737847e+00  max_dmdt=2.276801e-03
# [ Info: step =  192  step_size=7.371053e-01  max_dmdt=1.478947e-02
# [ Info: step =  193  step_size=5.023571e-01  max_dmdt=1.814796e-02
# [ Info: step =  194  step_size=2.220916e-01  max_dmdt=1.683452e-02
# [ Info: step =  195  step_size=1.763097e-01  max_dmdt=6.132170e-03
# [ Info: step =  196  step_size=1.260172e-01  max_dmdt=2.808571e-03
# [ Info: step =  197  step_size=3.280797e-01  max_dmdt=1.646516e-03
# [ Info: step =  198  step_size=3.702106e-01  max_dmdt=1.424245e-03
# [ Info: step =  199  step_size=1.369006e+02  max_dmdt=1.340634e-03
# [ Info: step =  200  step_size=2.150105e-01  max_dmdt=7.728824e-02
# [ Info: step =  201  step_size=1.289061e-01  max_dmdt=5.262428e-02
# [ Info: step =  202  step_size=1.253385e-01  max_dmdt=2.016973e-02
# [ Info: step =  203  step_size=9.308559e-01  max_dmdt=1.690750e-02
# [ Info: step =  204  step_size=1.027800e+00  max_dmdt=5.333300e-03
# [ Info: step =  205  step_size=4.204498e+00  max_dmdt=4.728454e-03
# [ Info: step =  206  step_size=2.568377e-01  max_dmdt=5.308530e-02
# [ Info: step =  207  step_size=2.115028e-01  max_dmdt=1.372876e-02
# [ Info: step =  208  step_size=1.273053e-01  max_dmdt=7.682032e-03
# [ Info: step =  209  step_size=1.350781e-01  max_dmdt=1.741797e-03
# [ Info: step =  210  step_size=2.644832e-01  max_dmdt=1.403632e-03
# [ Info: step =  211  step_size=1.490604e+01  max_dmdt=1.293731e-03
# [ Info: step =  212  step_size=2.521086e+00  max_dmdt=5.860767e-03
# [ Info: step =  213  step_size=4.025725e-01  max_dmdt=4.615768e-02
# [ Info: step =  214  step_size=1.287974e-01  max_dmdt=5.991789e-02
# [ Info: step =  215  step_size=1.258589e-01  max_dmdt=7.135439e-03
# [ Info: step =  216  step_size=1.623926e-01  max_dmdt=3.642284e-03
# [ Info: step =  217  step_size=6.325067e-01  max_dmdt=2.366765e-03
# [ Info: step =  218  step_size=4.352494e-01  max_dmdt=2.275844e-03
# [ Info: step =  219  step_size=2.380952e+00  max_dmdt=1.531978e-03
# [ Info: step =  220  step_size=2.059339e-01  max_dmdt=8.504010e-03
# [ Info: step =  221  step_size=2.086007e-01  max_dmdt=1.848266e-03
# [ Info: step =  222  step_size=1.438888e-01  max_dmdt=1.243945e-03
# [ Info: step =  223  step_size=1.773100e+00  max_dmdt=9.786925e-04
# [ Info: step =  224  step_size=2.026291e-01  max_dmdt=1.808581e-03
# [ Info: step =  225  step_size=5.269793e-01  max_dmdt=1.233077e-03
# [ Info: step =  226  step_size=1.261560e-01  max_dmdt=2.068450e-03
# [ Info: step =  227  step_size=2.272429e-01  max_dmdt=8.805519e-04
# [ Info: step =  228  step_size=3.658098e-01  max_dmdt=8.615430e-04
# [ Info: step =  229  step_size=2.667747e+02  max_dmdt=8.595972e-04
# [ Info: step =  230  step_size=2.416271e-01  max_dmdt=6.283974e-02
# [ Info: step =  231  step_size=1.254720e-01  max_dmdt=5.639373e-02
# [ Info: step =  232  step_size=1.248153e-01  max_dmdt=7.609194e-03
# [ Info: step =  233  step_size=3.948627e+00  max_dmdt=6.870520e-03
# [ Info: step =  234  step_size=1.851169e+00  max_dmdt=8.052871e-03
# [ Info: step =  235  step_size=8.296201e-01  max_dmdt=3.273921e-02
# [ Info: step =  236  step_size=2.076063e-01  max_dmdt=8.896043e-02
# [ Info: step =  237  step_size=1.834786e-01  max_dmdt=2.353817e-02
# [ Info: step =  238  step_size=1.587560e-01  max_dmdt=7.228943e-03
# [ Info: step =  239  step_size=2.619109e-01  max_dmdt=3.899755e-03
# [ Info: step =  240  step_size=2.927216e-01  max_dmdt=2.660587e-03
# [ Info: step =  241  step_size=5.758891e+00  max_dmdt=2.417540e-03
# [ Info: step =  242  step_size=2.737376e-01  max_dmdt=1.579552e-02
# [ Info: step =  243  step_size=1.440016e-01  max_dmdt=1.417947e-02
# [ Info: step =  244  step_size=1.401852e-01  max_dmdt=1.187372e-03
# [ Info: step =  245  step_size=1.267036e+00  max_dmdt=9.265545e-04
# [ Info: step =  246  step_size=9.040701e-01  max_dmdt=7.056759e-04
# [ Info: step =  247  step_size=1.443685e+00  max_dmdt=1.565497e-03
# [ Info: step =  248  step_size=1.252344e-01  max_dmdt=1.332232e-02
# [ Info: step =  249  step_size=1.253702e-01  max_dmdt=8.278642e-04
# [ Info: step =  250  step_size=1.497697e-01  max_dmdt=5.060147e-04
# [ Info: step =  251  step_size=2.787673e+01  max_dmdt=4.924636e-04
# [ Info: step =  252  step_size=5.403107e+00  max_dmdt=2.003862e-03
# [ Info: step =  253  step_size=5.197961e-01  max_dmdt=4.091969e-02
# [ Info: step =  254  step_size=1.835448e-01  max_dmdt=5.552188e-02
# [ Info: step =  255  step_size=1.672024e-01  max_dmdt=1.334119e-02
# [ Info: step =  256  step_size=1.385080e-01  max_dmdt=3.611445e-03
# [ Info: step =  257  step_size=1.775510e-01  max_dmdt=1.474754e-03
# [ Info: step =  258  step_size=3.043171e-01  max_dmdt=8.127047e-04
# [ Info: step =  259  step_size=3.018605e+00  max_dmdt=5.018346e-04
# [ Info: step =  260  step_size=2.876255e-01  max_dmdt=2.134785e-03
# [ Info: step =  261  step_size=2.406221e-01  max_dmdt=2.214052e-03
# [ Info: step =  262  step_size=1.289796e-01  max_dmdt=1.927766e-03
# [ Info: step =  263  step_size=2.133781e-01  max_dmdt=4.294995e-04
# [ Info: step =  264  step_size=3.574550e-01  max_dmdt=4.130869e-04
# [ Info: step =  265  step_size=5.248295e+01  max_dmdt=4.047880e-04
# [ Info: step =  266  step_size=2.049243e-01  max_dmdt=2.053987e-02
# [ Info: step =  267  step_size=1.307793e-01  max_dmdt=1.338065e-02
# [ Info: step =  268  step_size=1.271726e-01  max_dmdt=3.016410e-03
# [ Info: step =  269  step_size=8.352499e-01  max_dmdt=2.398947e-03
# [ Info: step =  270  step_size=7.316388e-01  max_dmdt=8.710229e-04
# [ Info: step =  271  step_size=6.255200e+00  max_dmdt=7.583354e-04
# [ Info: step =  272  step_size=1.456607e-01  max_dmdt=1.307099e-02
# [ Info: step =  273  step_size=1.320546e-01  max_dmdt=1.830491e-03
# [ Info: step =  274  step_size=1.291231e-01  max_dmdt=8.155855e-04
# [ Info: step =  275  step_size=1.684695e+00  max_dmdt=6.253205e-04
# [ Info: step =  276  step_size=4.908893e-01  max_dmdt=1.160220e-03
# [ Info: step =  277  step_size=8.629762e-01  max_dmdt=4.116699e-04
# [ Info: step =  278  step_size=1.414627e-01  max_dmdt=8.001204e-04
# [ Info: step =  279  step_size=2.582187e-01  max_dmdt=3.857928e-04
# [ Info: step =  280  step_size=1.368430e-01  max_dmdt=3.837458e-04
# [ Info: step =  281  step_size=7.303023e+00  max_dmdt=3.452540e-04
# [ Info: step =  282  step_size=6.505977e-01  max_dmdt=6.983099e-04
# [ Info: step =  283  step_size=3.565571e-01  max_dmdt=1.518187e-03
# [ Info: step =  284  step_size=1.253293e-01  max_dmdt=2.546752e-03
# [ Info: step =  285  step_size=1.288890e-01  max_dmdt=3.490052e-04
# [ Info: step =  286  step_size=1.612855e-01  max_dmdt=3.064068e-04
# [ Info: step =  287  step_size=1.549635e+02  max_dmdt=3.011029e-04
# [ Info: step =  288  step_size=4.890624e+00  max_dmdt=3.753032e-03
# [ Info: step =  289  step_size=2.825413e-01  max_dmdt=5.779730e-02
# [ Info: step =  290  step_size=1.824750e-01  max_dmdt=3.361611e-02
# [ Info: step =  291  step_size=1.695065e-01  max_dmdt=1.095795e-02
# [ Info: step =  292  step_size=1.416822e-01  max_dmdt=4.553031e-03
# [ Info: step =  293  step_size=2.556849e-01  max_dmdt=2.847082e-03
# [ Info: step =  294  step_size=4.059314e-01  max_dmdt=1.490504e-03
# [ Info: step =  295  step_size=6.623657e-01  max_dmdt=8.642652e-04
# [ Info: step =  296  step_size=1.327378e-01  max_dmdt=1.529756e-03
# [ Info: step =  297  step_size=1.314560e-01  max_dmdt=4.451684e-04
# [ Info: step =  298  step_size=1.406156e-01  max_dmdt=3.586090e-04
# [ Info: step =  299  step_size=1.348385e+01  max_dmdt=3.372562e-04
# [ Info: step =  300  step_size=1.393535e+00  max_dmdt=2.247967e-03
# [ Info: step =  301  step_size=1.097293e+00  max_dmdt=1.624029e-03
# [ Info: step =  302  step_size=1.361578e-01  max_dmdt=5.578220e-03
# [ Info: step =  303  step_size=1.272194e-01  max_dmdt=1.874120e-03
# [ Info: step =  304  step_size=1.456098e-01  max_dmdt=9.713215e-04
# [ Info: step =  305  step_size=7.857589e-01  max_dmdt=6.056016e-04
# [ Info: step =  306  step_size=4.459898e-01  max_dmdt=5.224502e-04
# [ Info: step =  307  step_size=1.652891e+00  max_dmdt=2.714179e-04
# [ Info: step =  308  step_size=1.826988e-01  max_dmdt=1.264057e-03
# [ Info: step =  309  step_size=2.108481e-01  max_dmdt=2.910631e-04
# [ Info: step =  310  step_size=1.267803e-01  max_dmdt=2.511719e-04
# [ Info: step =  311  step_size=1.510855e+00  max_dmdt=1.969029e-04
# [ Info: step =  312  step_size=1.145529e+00  max_dmdt=2.069109e-04
# [ Info: step =  313  step_size=3.152677e+01  max_dmdt=2.894057e-04
# [ Info: step =  314  step_size=1.280326e-01  max_dmdt=3.718536e-02
# [ Info: step =  315  step_size=1.266738e-01  max_dmdt=6.092339e-03
# [ Info: step =  316  step_size=1.799293e-01  max_dmdt=2.570780e-03
# [ Info: step =  317  step_size=2.766631e-01  max_dmdt=9.561959e-04
# [ Info: step =  318  step_size=3.320710e-01  max_dmdt=2.935710e-04
# [ Info: step =  319  step_size=3.783474e+00  max_dmdt=2.128849e-04
# [ Info: step =  320  step_size=1.804331e-01  max_dmdt=1.630736e-03
# [ Info: step =  321  step_size=1.811849e-01  max_dmdt=4.693602e-04
# [ Info: step =  322  step_size=1.380770e-01  max_dmdt=2.720357e-04
# [ Info: step =  323  step_size=1.791492e+00  max_dmdt=2.138336e-04
# [ Info: step =  324  step_size=3.781536e-01  max_dmdt=3.599657e-04
# [ Info: step =  325  step_size=9.078461e-01  max_dmdt=3.243452e-04
# [ Info: step =  326  step_size=1.254316e-01  max_dmdt=1.200445e-03
# [ Info: step =  327  step_size=1.309677e-01  max_dmdt=1.979885e-04
# [ Info: step =  328  step_size=1.733824e-01  max_dmdt=1.862355e-04
# [ Info: step =  329  step_size=1.452655e+02  max_dmdt=1.843691e-04
# [ Info: step =  330  step_size=1.175004e+00  max_dmdt=4.974701e-03
# [ Info: step =  331  step_size=4.374929e-01  max_dmdt=1.097856e-02
# [ Info: step =  332  step_size=1.867565e-01  max_dmdt=1.253741e-02
# [ Info: step =  333  step_size=1.445777e-01  max_dmdt=3.061225e-03
# [ Info: step =  334  step_size=1.312562e-01  max_dmdt=5.353205e-04
# [ Info: step =  335  step_size=2.424138e-01  max_dmdt=2.764607e-04
# [ Info: step =  336  step_size=3.593903e-01  max_dmdt=2.368584e-04
# [ Info: step =  337  step_size=1.011462e+01  max_dmdt=2.208236e-04
# [ Info: step =  338  step_size=1.769161e-01  max_dmdt=2.296395e-03
# [ Info: step =  339  step_size=1.281070e-01  max_dmdt=8.317779e-04
# [ Info: step =  340  step_size=1.253578e-01  max_dmdt=2.077421e-04
# [ Info: step =  341  step_size=2.599044e+00  max_dmdt=1.642191e-04
# [ Info: step =  342  step_size=4.880241e-01  max_dmdt=6.323822e-04
# [ Info: step =  343  step_size=7.263286e-01  max_dmdt=1.720825e-04
# [ Info: step =  344  step_size=1.603444e-01  max_dmdt=6.066594e-04
# [ Info: step =  345  step_size=2.300350e-01  max_dmdt=1.336170e-04
# [ Info: step =  346  step_size=1.892191e-01  max_dmdt=1.219623e-04
# [ Info: step =  347  step_size=5.402364e+01  max_dmdt=1.191797e-04
# [ Info: step =  348  step_size=2.355515e-01  max_dmdt=1.851153e-03
# [ Info: step =  349  step_size=1.318473e-01  max_dmdt=1.346185e-03
# [ Info: step =  350  step_size=1.256101e-01  max_dmdt=2.410850e-04
# [ Info: step =  351  step_size=6.605228e-01  max_dmdt=1.575226e-04
# [ Info: step =  352  step_size=4.235471e-01  max_dmdt=1.335892e-04
# [ Info: step =  353  step_size=5.813383e+00  max_dmdt=1.371770e-04
# [ Info: step =  354  step_size=1.571240e-01  max_dmdt=2.896198e-03
# [ Info: step =  355  step_size=1.560369e-01  max_dmdt=2.443603e-04
# [ Info: step =  356  step_size=1.651814e-01  max_dmdt=1.494374e-04
# [ Info: step =  357  step_size=4.353062e+00  max_dmdt=1.174868e-04
# [ Info: step =  358  step_size=2.757084e-01  max_dmdt=6.741805e-04
# [ Info: step =  359  step_size=2.827135e-01  max_dmdt=2.649747e-04
# [ Info: step =  360  step_size=1.256555e-01  max_dmdt=2.677795e-04
# [ Info: step =  361  step_size=1.804484e-01  max_dmdt=1.101521e-04
# [ Info: step =  362  step_size=4.801145e-01  max_dmdt=1.085120e-04
# [ Info: step =  363  step_size=2.177955e+02  max_dmdt=1.060373e-04
# [ Info: step =  364  step_size=3.164855e-01  max_dmdt=3.605104e-03
# [ Info: step =  365  step_size=1.257410e-01  max_dmdt=4.520658e-03
# [ Info: step =  366  step_size=1.247984e-01  max_dmdt=2.646741e-04
# [ Info: step =  367  step_size=6.995037e-01  max_dmdt=1.893790e-04
# [ Info: step =  368  step_size=5.854572e-01  max_dmdt=1.060573e-04
# [ Info: step =  369  step_size=5.427377e+00  max_dmdt=1.004726e-04
# [ Info: step =  370  step_size=1.592665e-01  max_dmdt=2.253104e-03
# [ Info: step =  371  step_size=1.527237e-01  max_dmdt=1.352701e-04
# [ Info: step =  372  step_size=1.561202e-01  max_dmdt=6.871244e-05
# [ Info: max_dmdt is less than stopping_dmdt=0.0001, Done!

# %% [markdown]
# After obtain the skyrmion, we use the following script to plot the skyrmion

# %%
plot_m(sim)
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
