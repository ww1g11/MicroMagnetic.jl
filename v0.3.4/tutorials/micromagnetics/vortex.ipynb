# %% [markdown]
# We import MicroMagnetic and use double float precision in the simulation

# %%
using MicroMagnetic
using CairoMakie

# %% [markdown]
# In this example, the studied system is a round nanodisk. Since we are using finite different method,
# we create a FDMesh with dimensions 200nm x 200nm x 20 nm.

# %%
mesh =  FDMesh(dx=2e-9, dy=2e-9, dz=5e-9, nx=100, ny=100, nz=4);

# %% [markdown]
# Create a cylindrical shape with a diameter of 100 nm

# %%
geo = Cylinder(radius=100e-9);

# %% [markdown]
# To start the simulation, we need to give an initial state.
# Here we use a function to give the initial state. The function should take six parameters `(i,j,k,dx,dy,dz)`.

# %%
function init_fun(i,j,k,dx,dy,dz)
  x = i-50.5
  y = j-50.5
  r = (x^2+y^2)^0.5
  if r<20
    return (0,0,1)
  end
  return (y/r, -x/r, 0)
end
# Out:
# init_fun (generic function with 1 method)

# %% [markdown]
# Create a Sim instance and then relax the system

# %%
sim = create_sim(mesh, shape=geo, Ms=8e5, A = 1.3e-11, demag=true, m0=init_fun);
relax(sim, maxsteps=5000, stopping_dmdt=0.1)
save_vtk(sim, "vortex")
# Out:
# [ Info: MicroSim has been created.
# [ Info: Exchange has been added.
# [ Info: Running Driver : MicroMagnetic.EnergyMinimization{Float64}.
# [ Info: step =    0  step_size=9.049774e-16  max_dmdt=8.301381e+04
# [ Info: step =    1  step_size=9.186824e-13  max_dmdt=6.906170e+04
# [ Info: step =    2  step_size=3.513763e-13  max_dmdt=1.224619e+05
# [ Info: step =    3  step_size=2.590682e-13  max_dmdt=6.192582e+04
# [ Info: step =    4  step_size=2.067183e-13  max_dmdt=2.412649e+04
# [ Info: step =    5  step_size=3.812805e-13  max_dmdt=9.914355e+03
# [ Info: step =    6  step_size=9.438009e-13  max_dmdt=8.063586e+03
# [ Info: step =    7  step_size=2.809277e-12  max_dmdt=7.883935e+03
# [ Info: step =    8  step_size=2.054424e-13  max_dmdt=6.850703e+04
# [ Info: step =    9  step_size=1.873147e-13  max_dmdt=7.001177e+03
# [ Info: step =   10  step_size=1.826901e-13  max_dmdt=3.286380e+03
# [ Info: step =   11  step_size=1.193797e-11  max_dmdt=3.002782e+03
# [ Info: step =   12  step_size=2.595546e-12  max_dmdt=6.860042e+03
# [ Info: step =   13  step_size=1.159989e-12  max_dmdt=2.159346e+04
# [ Info: step =   14  step_size=2.830308e-13  max_dmdt=7.646374e+04
# [ Info: step =   15  step_size=2.359746e-13  max_dmdt=2.045761e+04
# [ Info: step =   16  step_size=1.910374e-13  max_dmdt=6.888838e+03
# [ Info: step =   17  step_size=2.941599e-13  max_dmdt=3.108904e+03
# [ Info: step =   18  step_size=4.501993e-13  max_dmdt=2.424135e+03
# [ Info: step =   19  step_size=5.106799e-12  max_dmdt=2.157739e+03
# [ Info: step =   20  step_size=2.203157e-13  max_dmdt=1.292391e+04
# [ Info: step =   21  step_size=1.931790e-13  max_dmdt=3.627230e+03
# [ Info: step =   22  step_size=1.824029e-13  max_dmdt=2.271368e+03
# [ Info: step =   23  step_size=6.251646e-12  max_dmdt=2.160099e+03
# [ Info: step =   24  step_size=8.261469e-13  max_dmdt=6.012667e+03
# [ Info: step =   25  step_size=8.511238e-13  max_dmdt=2.756031e+03
# [ Info: step =   26  step_size=1.874925e-13  max_dmdt=8.264390e+03
# [ Info: step =   27  step_size=1.879313e-13  max_dmdt=2.118860e+03
# [ Info: step =   28  step_size=1.779955e-13  max_dmdt=2.001888e+03
# [ Info: step =   29  step_size=1.920620e-11  max_dmdt=1.842511e+03
# [ Info: step =   30  step_size=1.628885e-12  max_dmdt=7.377226e+03
# [ Info: step =   31  step_size=5.248098e-13  max_dmdt=1.691700e+04
# [ Info: step =   32  step_size=2.322140e-13  max_dmdt=2.771491e+04
# [ Info: step =   33  step_size=1.685207e-13  max_dmdt=1.112387e+04
# [ Info: step =   34  step_size=1.655598e-13  max_dmdt=1.828110e+03
# [ Info: step =   35  step_size=1.253672e-12  max_dmdt=1.706677e+03
# [ Info: step =   36  step_size=4.681759e-13  max_dmdt=1.795711e+03
# [ Info: step =   37  step_size=1.003407e-12  max_dmdt=1.498883e+03
# [ Info: step =   38  step_size=4.380655e-13  max_dmdt=1.496252e+03
# [ Info: step =   39  step_size=1.902319e-12  max_dmdt=1.334838e+03
# [ Info: step =   40  step_size=1.956195e-13  max_dmdt=2.750230e+03
# [ Info: step =   41  step_size=1.947500e-13  max_dmdt=1.257123e+03
# [ Info: step =   42  step_size=1.773297e-13  max_dmdt=1.202178e+03
# [ Info: step =   43  step_size=8.313778e-12  max_dmdt=1.177608e+03
# [ Info: step =   44  step_size=1.922610e-12  max_dmdt=1.372166e+03
# [ Info: step =   45  step_size=3.935763e-13  max_dmdt=6.232379e+03
# [ Info: step =   46  step_size=2.099964e-13  max_dmdt=6.495135e+03
# [ Info: step =   47  step_size=1.673255e-13  max_dmdt=1.892626e+03
# [ Info: step =   48  step_size=1.651615e-13  max_dmdt=6.860312e+02
# [ Info: step =   49  step_size=3.336233e-12  max_dmdt=6.603875e+02
# [ Info: step =   50  step_size=5.605997e-13  max_dmdt=8.831675e+02
# [ Info: step =   51  step_size=4.695030e-13  max_dmdt=8.019748e+02
# [ Info: step =   52  step_size=3.179552e-13  max_dmdt=6.363754e+02
# [ Info: step =   53  step_size=1.146585e-12  max_dmdt=5.349652e+02
# [ Info: step =   54  step_size=3.024219e-13  max_dmdt=5.220583e+02
# [ Info: step =   55  step_size=6.241086e-13  max_dmdt=4.939436e+02
# [ Info: step =   56  step_size=1.682948e-13  max_dmdt=5.478171e+02
# [ Info: step =   57  step_size=2.439444e-13  max_dmdt=4.706073e+02
# [ Info: step =   58  step_size=6.920382e-13  max_dmdt=4.648545e+02
# [ Info: step =   59  step_size=2.107799e-11  max_dmdt=4.487686e+02
# [ Info: step =   60  step_size=3.702600e-13  max_dmdt=3.356581e+03
# [ Info: step =   61  step_size=1.631485e-13  max_dmdt=4.257794e+03
# [ Info: step =   62  step_size=1.631086e-13  max_dmdt=6.685374e+01
# [ Info: step =   63  step_size=1.621423e-12  max_dmdt=6.246772e+01
# [ Info: step =   64  step_size=8.128856e-13  max_dmdt=3.491470e+01
# [ Info: step =   65  step_size=7.701467e-13  max_dmdt=5.236382e+01
# [ Info: step =   66  step_size=2.593696e-13  max_dmdt=9.227302e+01
# [ Info: step =   67  step_size=2.763803e-13  max_dmdt=2.494078e+01
# [ Info: step =   68  step_size=2.023368e-13  max_dmdt=2.241808e+01
# [ Info: step =   69  step_size=3.757898e-12  max_dmdt=2.100429e+01
# [ Info: step =   70  step_size=2.017385e-12  max_dmdt=1.965216e+01
# [ Info: step =   71  step_size=4.120725e-13  max_dmdt=1.521075e+02
# [ Info: step =   72  step_size=1.717140e-13  max_dmdt=2.068606e+02
# [ Info: step =   73  step_size=1.720364e-13  max_dmdt=1.164772e+01
# [ Info: step =   74  step_size=1.795205e-13  max_dmdt=8.831760e+00
# [ Info: step =   75  step_size=1.552948e-11  max_dmdt=8.568429e+00
# [ Info: step =   76  step_size=1.251853e-11  max_dmdt=1.085848e+01
# [ Info: step =   77  step_size=3.091306e-13  max_dmdt=4.359707e+02
# [ Info: step =   78  step_size=2.075533e-13  max_dmdt=2.022536e+02
# [ Info: step =   79  step_size=1.838359e-13  max_dmdt=4.721473e+01
# [ Info: step =   80  step_size=1.661445e-13  max_dmdt=7.028362e+00
# [ Info: step =   81  step_size=2.191587e-13  max_dmdt=5.957628e+00
# [ Info: step =   82  step_size=4.081704e-13  max_dmdt=5.257535e+00
# [ Info: step =   83  step_size=3.990627e-12  max_dmdt=4.519133e+00
# [ Info: step =   84  step_size=2.328566e-12  max_dmdt=6.965694e+00
# [ Info: step =   85  step_size=5.962948e-13  max_dmdt=1.223651e+01
# [ Info: step =   86  step_size=1.739465e-13  max_dmdt=3.142441e+01
# [ Info: step =   87  step_size=1.674000e-13  max_dmdt=3.278655e+00
# [ Info: step =   88  step_size=2.052763e-13  max_dmdt=2.471927e+00
# [ Info: step =   89  step_size=6.874610e-13  max_dmdt=2.036013e+00
# [ Info: step =   90  step_size=4.588349e-13  max_dmdt=1.498989e+00
# [ Info: step =   91  step_size=2.529361e-12  max_dmdt=1.399465e+00
# [ Info: step =   92  step_size=3.323199e-13  max_dmdt=1.953731e+00
# [ Info: step =   93  step_size=2.850991e-13  max_dmdt=1.335946e+00
# [ Info: step =   94  step_size=1.744242e-13  max_dmdt=9.653115e-01
# [ Info: step =   95  step_size=4.340235e-13  max_dmdt=9.327945e-01
# [ Info: step =   96  step_size=6.272401e-13  max_dmdt=9.171990e-01
# [ Info: step =   97  step_size=1.046582e-11  max_dmdt=8.872248e-01
# [ Info: step =   98  step_size=1.840923e-13  max_dmdt=1.352900e+01
# [ Info: step =   99  step_size=1.640665e-13  max_dmdt=1.696773e+00
# [ Info: step =  100  step_size=1.644273e-13  max_dmdt=4.986966e-01
# [ Info: step =  101  step_size=5.058299e-12  max_dmdt=4.617754e-01
# [ Info: step =  102  step_size=1.033329e-12  max_dmdt=8.666690e-01
# [ Info: step =  103  step_size=3.790015e-13  max_dmdt=1.790214e+00
# [ Info: step =  104  step_size=2.470265e-13  max_dmdt=1.007445e+00
# [ Info: step =  105  step_size=2.743118e-13  max_dmdt=2.958843e-01
# [ Info: step =  106  step_size=3.371396e-13  max_dmdt=2.747556e-01
# [ Info: step =  107  step_size=1.915603e-11  max_dmdt=2.683414e-01
# [ Info: step =  108  step_size=3.272820e-12  max_dmdt=5.093062e-01
# [ Info: step =  109  step_size=1.899418e-13  max_dmdt=8.101424e+00
# [ Info: step =  110  step_size=1.709128e-13  max_dmdt=1.283798e+00
# [ Info: step =  111  step_size=1.745761e-13  max_dmdt=4.002174e-01
# [ Info: step =  112  step_size=2.317933e-13  max_dmdt=3.406219e-01
# [ Info: step =  113  step_size=9.441437e-13  max_dmdt=2.881745e-01
# [ Info: step =  114  step_size=1.234795e-12  max_dmdt=9.228293e-02
# [ Info: max_dmdt is less than stopping_dmdt=0.1, Done!
# 1-element Vector{String}:
#  "vortex.vts"

# %% [markdown]
# We plot the magnetization distribution using the plot_m function

# %%
plot_m(sim, figsize=(400, 400), arrows=(30,30))
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
